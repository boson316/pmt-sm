# %% [markdown]
# # 01 ViT-FPN Demo (PMT-SM Step1)
#
# 示範：載入 ViT backbone、取得多尺度特徵、與 FPN 融合。

# %%
import sys
sys.path.insert(0, '..')
import torch
import timm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = timm.create_model('vit_base_patch16_224', pretrained=True, num_classes=0)
model.eval()
x = torch.randn(1, 3, 224, 224).to(device)
with torch.no_grad():
    out = model(x)
print('ViT output shape:', out.shape)

# %% [markdown]
# FPN 與完整 PMT-SM 訓練請見專案根目錄 `train_pmt_sm.py` 與 `docs/architecture.md`。
